# %%
import re

def preprocess_text(text):

    text = text.lower()

    text = re.sub(r'[^a-z0-9\s]', '', text)

    words = text.split()

    return words

cleaned_text = input("Enter your text here:  ")
tokens = preprocess_text(cleaned_text)

print( tokens)
# Out:
# Enter your text here:  Hello this is my first task of my internship!
# ['hello', 'this', 'is', 'my', 'first', 'task', 'of', 'my', 'internship']
